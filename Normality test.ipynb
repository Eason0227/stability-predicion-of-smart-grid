shapiro.test(Tree_Weighted_Rotation_forest_Mini_PCA)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  Random_forest
# W = 0.93749, p-value = 0.5255
# 	Shapiro-Wilk normality test
#
# data:  Rotation_forest
# W = 0.9623, p-value = 0.8118
# 	Shapiro-Wilk normality test
#
# data:  Rotation_Forest_Mini_PCA
# W = 0.93288, p-value = 0.4768
# 	Shapiro-Wilk normality test
#
# data:  Strength_Rotation_forest
# W = 0.97508, p-value = 0.9335
# 	Shapiro-Wilk normality test
#
# data:  Strength_Random_forest
# W = 0.93414, p-value = 0.4898
# 	Shapiro-Wilk normality test
#
# data:  strength_Rotation_Forest_Mini_PCA
# W = 0.95117, p-value = 0.6823
# 	Shapiro-Wilk normality test
#
# data:  Tree_Weighted_Random_forest
# W = 0.92325, p-value = 0.3848
# 	Shapiro-Wilk normality test
#
# data:  Tree_Weighted_Rotation_forest
# W = 0.99182, p-value = 0.9985
# 	Shapiro-Wilk normality test
#
# data:  Tree_Weighted_Rotation_forest_Mini_PCA
# W = 0.92428, p-value = 0.3941

# %%
# 安裝 nortest 套件
install.packages("nortest")

# 載入 nortest 套件
library(nortest)

ad.test(Random_forest)
ad.test(Rotation_forest)
ad.test(Rotation_Forest_Mini_PCA)

ad.test(Strength_Rotation_forest)
ad.test(Strength_Random_forest)
ad.test(strength_Rotation_Forest_Mini_PCA)

ad.test(Tree_Weighted_Random_forest)
ad.test(Tree_Weighted_Rotation_forest)
ad.test(Tree_Weighted_Rotation_forest_Mini_PCA)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# 	Anderson-Darling normality test
#
# data:  Random_forest
# A = 0.32065, p-value = 0.4681
# 	Anderson-Darling normality test
#
# data:  Rotation_forest
# A = 0.22797, p-value = 0.744
# 	Anderson-Darling normality test
#
# data:  Rotation_Forest_Mini_PCA
# A = 0.31432, p-value = 0.4855
# 	Anderson-Darling normality test
#
# data:  Strength_Rotation_forest
# A = 0.22491, p-value = 0.7549
# 	Anderson-Darling normality test
#
# data:  Strength_Random_forest
# A = 0.32226, p-value = 0.4638
# 	Anderson-Darling normality test
#
# data:  strength_Rotation_Forest_Mini_PCA
# A = 0.27843, p-value = 0.5672
# 	Anderson-Darling normality test
#
# data:  Tree_Weighted_Random_forest
# A = 0.35966, p-value = 0.3729
# 	Anderson-Darling normality test
#
# data:  Tree_Weighted_Rotation_forest
# A = 0.13263, p-value = 0.9684
# 	Anderson-Darling normality test
#
# data:  Tree_Weighted_Rotation_forest_Mini_PCA
# ...
